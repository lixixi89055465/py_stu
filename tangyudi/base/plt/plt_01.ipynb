# %%
import pandas as pd
unrate=pd.read_csv('tangyudi/base/plt/UNRATE.csv')
unrate['DATE']=pd.to_datetime(unrate['DATE'])
print(unrate.head(12))
print('a')
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0
# a

# %%
import matplotlib.pyplot as plt
plt.plot()
plt.show()

# %%
first_twelve=unrate[0:12]
plt.plot(first_twelve['DATE'],first_twelve['VALUE'])
plt.show()

# %%
plt.plot(first_twelve['DATE'],first_twelve['VALUE'])
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(first_twelve['DATE'],first_twelve['VALUE'])
plt.xticks(rotation=45)
plt.xlabel('MONTH')
plt.ylabel('Every month')
plt.title('every day title')
plt.show()

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot

# %%
import numpy as np
fig=plt.figure(figsize=(2,3))
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)
ax1.plot(np.random.randint(1,5,5),np.arange(5))
ax2.plot(np.arange(10)*3,np.arange(10))
plt.show()

# %%
unrate['MONTH']=unrate['DATE'].dt.month

fig=plt.figure(figsize=(6,3))
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax1.plot(np.random.randint(1,5,5),np.arange(5))
ax2.plot(np.arange(10)*3,np.arange(10))
plt.show()

# %%
fig=plt.figure(figsize=(10,6))
colors=['red','blue','green','orange','black']
for i in range(5):
    start_index=i*12
    end_index=start_index+12
    subset=unrate[start_index:end_index]
    plt.plot(subset['MONTH'],subset['VALUE'],c=colors[i])


plt.legend(loc='best')
plt.show()
# print(help(plt.legend))
# Out:
# No handles with labels found to put in legend.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-6ed6b83ebc05> in <module>
#       3
#       4 num_cols=['aa','bb','cc','dd','ee']
# ----> 5 bar_heights=norm_reviews.ix[0,num_cols].values
#       6
#       7 print(bar_heights)
#
# NameError: name 'norm_reviews' is not defined
